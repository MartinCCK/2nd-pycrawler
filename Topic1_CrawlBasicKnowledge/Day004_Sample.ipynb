# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11958757158","type":"IssueCommentEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":234436422,"name":"thurow/dev-radar","url":"https://api.github.com/repos/thurow/dev-radar"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/thurow/dev-radar/issues/1","repository_url":"https://api.github.com/repos/thurow/dev-radar","labels_url":"https://api.github.com/repos/thurow/dev-radar/issues/1/labels{/name}","comments_url":"https://api.github.com/repos/thurow/dev-radar/issues/1/comments","events_url":"https://api.github.com/repos/thurow/dev-radar/issues/1/events","html_url":"https://github.com/thurow/dev-radar/pull/1","id":581418905,"node_id":"MDExOlB1bGxSZXF1ZXN0Mzg4NDgyMDY4","number":1,"title":"Bump acorn from 5.7.3 to 5.7.4 in /web","user":{"login":"dependabot[bot]","id":49699333,"node_id":"MDM6Qm90NDk2OTkzMzM=","avatar_url":"https://avatars0.githubusercontent.com/in/29110?v=4","gravatar_id":"","url":"https://api.github.com/users/dependabot%5Bbot%5D","html_url":"https://github.com/apps/dependabot","followers_url":"https://api.github.com/users/dependabot%5Bbot%5D/followers","following_url":"https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/dependabot%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/dependabot%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/dependabot%5Bbot%5D/repos","events_url":"https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/dependabot%5Bbot%5D/received_events","type":"Bot","site_admin":false},"labels":[{"id":1909887207,"node_id":"MDU6TGFiZWwxOTA5ODg3MjA3","url":"https://api.github.com/repos/thurow/dev-radar/labels/dependencies","name":"dependencies","color":"0366d6","default":false,"description":"Pull requests that update a dependency file"}],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":0,"created_at":"2020-03-14T23:33:01Z","updated_at":"2020-04-04T19:15:58Z","closed_at":null,"author_association":"NONE","pull_request":{"url":"https://api.github.com/repos/thurow/dev-radar/pulls/1","html_url":"https://github.com/thurow/dev-radar/pull/1","diff_url":"https://github.com/thurow/dev-radar/pull/1.diff","patch_url":"https://github.com/thurow/dev-radar/pull/1.patch"},"body":"[//]: # (dependabot-start)\\n⚠️  **Dependabot is rebasing this PR** ⚠️ \\n\\nIf you make any changes to it yourself then they will take precedence over the rebase.\\n\\n---\\n\\n[//]: # (dependabot-end)\\n\\nBumps [acorn](https://github.com/acornjs/acorn) from 5.7.3 to 5.7.4.\\n<details>\\n<summary>Commits</summary>\\n<ul>\\n<li><a href=\\"https://github.com/acornjs/acorn/commit/6370e90067552022710190319cbbbd8c43001957\\"><code>6370e90</code></a> Mark version 5.7.4</li>\\n<li><a href=\\"https://github.com/acornjs/acorn/commit/fbc15b1344f6dfb992f67b4bbf1357436247c8a0\\"><code>fbc15b1</code></a> More rigorously check surrogate pairs in regexp validator</li>\\n<li>See full diff in <a href=\\"https://github.com/acornjs/acorn/compare/5.7.3...5.7.4\\">compare view</a></li>\\n</ul>\\n</details>\\n<br />\\n\\n\\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=acorn&package-manager=npm_and_yarn&previous-version=5.7.3&new-version=5.7.4)](https://help.github.com/articles/configuring-automated-security-fixes)\\n\\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\\n\\n[//]: # (dependabot-a ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11958757158',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 234436422,
#    'name': 'thurow/dev-radar',
#    'url': 'https://api.github.com/repos/thurow/dev-radar'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/thurow/dev-radar/issues/1',
#     'repository_url': 'https://api.github.com/repos/thurow/dev-radar',
#     'labels_url': 'https://api.github.com/repos/thurow/dev-radar/issues/1/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/thurow/dev-radar/issues/1/comments',
#     'events_url': 'https://api.github.com/repos/thurow/dev-radar/issues/1/events',
#     'html_url': 'https://github.com/thurow/dev-radar/pull/1',
#     'id': 581418905,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mzg4NDgyMDY4',
#     'number': 1,
#     'title': 'Bump acorn from 5.7.3 to 5.7.4 in /web',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 1909887207,
#       'node_id': 'MDU6TGFiZWwxOTA5ODg3MjA3',
#       'url': 'https://api.github.com/repos/thurow/dev-radar/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-03-14T23:33:01Z',
#     'updated_at': '2020-04-04T19:15:58Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'pull_request': {'url': 'https://api.github.com/repos/thurow/dev-radar/pulls/1',
#      'html_url': 'https://github.com/thurow/dev-radar/pull/1',
#      'diff_url': 'https://github.com/thurow/dev-radar/pull/1.diff',
#      'patch_url': 'https://github.com/thurow/dev-radar/pull/1.patch'},
#     'body': '[//]: # (dependabot-start)\n⚠️  **Dependabot is rebasing this PR** ⚠️ \n\nIf you make any changes to it yourself then they will take precedence over the rebase.\n\n---\n\n[//]: # (dependabot-end)\n\nBumps [acorn](https://github.com/acornjs/acorn) from 5.7.3 to 5.7.4.\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/acornjs/acorn/commit/6370e90067552022710190319cbbbd8c43001957"><code>6370e90</code></a> Mark version 5.7.4</li>\n<li><a href="https://github.com/acornjs/acorn/commit/fbc15b1344f6dfb992f67b4bbf1357436247c8a0"><code>fbc15b1</code></a> More rigorously check surrogate pairs in regexp validator</li>\n<li>See full diff in <a href="https://github.com/acornjs/acorn/compare/5.7.3...5.7.4">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=acorn&package-manager=npm_and_yarn&previous-version=5.7.3&new-version=5.7.4)](https://help.github.com/articles/configuring-automated-security-fixes)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n\nYou can disable automated security fix PRs for this repo from the [Security Alerts page](https://github.com/thurow/dev-radar/network/alerts).\n\n</details>'},
#    'comment': {'url': 'https://api.github.com/repos/thurow/dev-radar/issues/comments/609076212',
#     'html_url': 'https://github.com/thurow/dev-radar/pull/1#issuecomment-609076212',
#     'issue_url': 'https://api.github.com/repos/thurow/dev-radar/issues/1',
#     'id': 609076212,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDYwOTA3NjIxMg==',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2020-04-04T19:15:58Z',
#     'updated_at': '2020-04-04T19:15:58Z',
#     'author_association': 'NONE',
#     'body': 'Looks like acorn is up-to-date now, so this is no longer needed.'}},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z'},
#  {'id': '11958757148',
#   'type': 'PushEvent',
#   'actor': {'id': 8469205,
#    'login': 'SensehacK',
#    'display_login': 'SensehacK',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SensehacK',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8469205?'},
#   'repo': {'id': 206435852,
#    'name': 'SensehacK/masters-comp-science',
#    'url': 'https://api.github.com/repos/SensehacK/masters-comp-science'},
#   'payload': {'push_id': 4868409330,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3683b942d687a83b759dffe77681ad7278eb4537',
#    'before': '4b0176d4c71ed4f4a7985895e619fd8a7fbf3600',
#    'commits': [{'sha': '3683b942d687a83b759dffe77681ad7278eb4537',
#      'author': {'email': 'kautilyasave@gmail.com', 'name': 'Kautilya'},
#      'message': '(CS639)Unit: assignment',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SensehacK/masters-comp-science/commits/3683b942d687a83b759dffe77681ad7278eb4537'}]},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z'},
#  {'id': '11958757153',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 148436575,
#    'name': 'Bazzer588/test-bp-356',
#    'url': 'https://api.github.com/repos/Bazzer588/test-bp-356'},
#   'payload': {'action': 'opened',
#    'number': 2,
#    'pull_request': {'url': 'https://api.github.com/repos/Bazzer588/test-bp-356/pulls/2',
#     'id': 398693207,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mzk4NjkzMjA3',
#     'html_url': 'https://github.com/Bazzer588/test-bp-356/pull/2',
#     'diff_url': 'https://github.com/Bazzer588/test-bp-356/pull/2.diff',
#     'patch_url': 'https://github.com/Bazzer588/test-bp-356/pull/2.patch',
#     'issue_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/issues/2',
#     'number': 2,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump acorn from 5.7.3 to 5.7.4',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [acorn](https://github.com/acornjs/acorn) from 5.7.3 to 5.7.4.\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/acornjs/acorn/commit/6370e90067552022710190319cbbbd8c43001957"><code>6370e90</code></a> Mark version 5.7.4</li>\n<li><a href="https://github.com/acornjs/acorn/commit/fbc15b1344f6dfb992f67b4bbf1357436247c8a0"><code>fbc15b1</code></a> More rigorously check surrogate pairs in regexp validator</li>\n<li>See full diff in <a href="https://github.com/acornjs/acorn/compare/5.7.3...5.7.4">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=acorn&package-manager=npm_and_yarn&previous-version=5.7.3&new-version=5.7.4)](https://help.github.com/articles/configuring-automated-security-fixes)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n\nYou can disable automated security fix PRs for this repo from the [Security Alerts page](https://github.com/Bazzer588/test-bp-356/network/alerts).\n\n</details>',
#     'created_at': '2020-04-04T19:15:58Z',
#     'updated_at': '2020-04-04T19:15:58Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/pulls/2/commits',
#     'review_comments_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/pulls/2/comments',
#     'review_comment_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/issues/2/comments',
#     'statuses_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/statuses/6454a8b0f0d04b3334d7820fbb916067ad00adee',
#     'head': {'label': 'Bazzer588:dependabot/npm_and_yarn/acorn-5.7.4',
#      'ref': 'dependabot/npm_and_yarn/acorn-5.7.4',
#      'sha': '6454a8b0f0d04b3334d7820fbb916067ad00adee',
#      'user': {'login': 'Bazzer588',
#       'id': 40038437,
#       'node_id': 'MDQ6VXNlcjQwMDM4NDM3',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/40038437?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Bazzer588',
#       'html_url': 'https://github.com/Bazzer588',
#       'followers_url': 'https://api.github.com/users/Bazzer588/followers',
#       'following_url': 'https://api.github.com/users/Bazzer588/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Bazzer588/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Bazzer588/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Bazzer588/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Bazzer588/orgs',
#       'repos_url': 'https://api.github.com/users/Bazzer588/repos',
#       'events_url': 'https://api.github.com/users/Bazzer588/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Bazzer588/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 148436575,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNDg0MzY1NzU=',
#       'name': 'test-bp-356',
#       'full_name': 'Bazzer588/test-bp-356',
#       'private': False,
#       'owner': {'login': 'Bazzer588',
#        'id': 40038437,
#        'node_id': 'MDQ6VXNlcjQwMDM4NDM3',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/40038437?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Bazzer588',
#        'html_url': 'https://github.com/Bazzer588',
#        'followers_url': 'https://api.github.com/users/Bazzer588/followers',
#        'following_url': 'https://api.github.com/users/Bazzer588/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Bazzer588/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Bazzer588/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Bazzer588/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Bazzer588/orgs',
#        'repos_url': 'https://api.github.com/users/Bazzer588/repos',
#        'events_url': 'https://api.github.com/users/Bazzer588/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Bazzer588/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Bazzer588/test-bp-356',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/Bazzer588/test-bp-356',
#       'forks_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/forks',
#       'keys_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/teams',
#       'hooks_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/events',
#       'assignees_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/tags',
#       'blobs_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/languages',
#       'stargazers_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/subscription',
#       'commits_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/merges',
#       'archive_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/downloads',
#       'issues_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/deployments',
#       'created_at': '2018-09-12T07:01:19Z',
#       'updated_at': '2020-02-10T00:36:58Z',
#       'pushed_at': '2020-04-04T19:15:57Z',
#       'git_url': 'git://github.com/Bazzer588/test-bp-356.git',
#       'ssh_url': 'git@github.com:Bazzer588/test-bp-356.git',
#       'clone_url': 'https://github.com/Bazzer588/test-bp-356.git',
#       'svn_url': 'https://github.com/Bazzer588/test-bp-356',
#       'homepage': None,
#       'size': 789,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'Bazzer588:master',
#      'ref': 'master',
#      'sha': '2cb82c3a43bd4586829932c5f72b8af4addd8339',
#      'user': {'login': 'Bazzer588',
#       'id': 40038437,
#       'node_id': 'MDQ6VXNlcjQwMDM4NDM3',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/40038437?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Bazzer588',
#       'html_url': 'https://github.com/Bazzer588',
#       'followers_url': 'https://api.github.com/users/Bazzer588/followers',
#       'following_url': 'https://api.github.com/users/Bazzer588/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Bazzer588/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Bazzer588/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Bazzer588/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Bazzer588/orgs',
#       'repos_url': 'https://api.github.com/users/Bazzer588/repos',
#       'events_url': 'https://api.github.com/users/Bazzer588/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Bazzer588/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 148436575,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNDg0MzY1NzU=',
#       'name': 'test-bp-356',
#       'full_name': 'Bazzer588/test-bp-356',
#       'private': False,
#       'owner': {'login': 'Bazzer588',
#        'id': 40038437,
#        'node_id': 'MDQ6VXNlcjQwMDM4NDM3',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/40038437?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Bazzer588',
#        'html_url': 'https://github.com/Bazzer588',
#        'followers_url': 'https://api.github.com/users/Bazzer588/followers',
#        'following_url': 'https://api.github.com/users/Bazzer588/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Bazzer588/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Bazzer588/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Bazzer588/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Bazzer588/orgs',
#        'repos_url': 'https://api.github.com/users/Bazzer588/repos',
#        'events_url': 'https://api.github.com/users/Bazzer588/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Bazzer588/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Bazzer588/test-bp-356',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/Bazzer588/test-bp-356',
#       'forks_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/forks',
#       'keys_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/teams',
#       'hooks_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/events',
#       'assignees_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/tags',
#       'blobs_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/languages',
#       'stargazers_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/subscription',
#       'commits_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/merges',
#       'archive_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/downloads',
#       'issues_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Bazzer588/test-bp-356/deployments',
#       'created_at': '2018-09-12T07:01:19Z',
#       'updated_at': '2020-02-10T00:36:58Z',
#       'pushed_at': '2020-04-04T19:15:57Z',
#       'git_url': 'git://github.com/Bazzer588/test-bp-356.git',
#       'ssh_url': 'git@github.com:Bazzer588/test-bp-356.git',
#       'clone_url': 'https://github.com/Bazzer588/test-bp-356.git',
#       'svn_url': 'https://github.com/Bazzer588/test-bp-356',
#       'homepage': None,
#       'size': 789,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Bazzer588/test-bp-356/pulls/2'},
#      'html': {'href': 'https://github.com/Bazzer588/test-bp-356/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/Bazzer588/test-bp-356/issues/2'},
#      'comments': {'href': 'https://api.github.com/repos/Bazzer588/test-bp-356/issues/2/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Bazzer588/test-bp-356/pulls/2/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Bazzer588/test-bp-356/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Bazzer588/test-bp-356/pulls/2/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Bazzer588/test-bp-356/statuses/6454a8b0f0d04b3334d7820fbb916067ad00adee'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 29,
#     'deletions': 24,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z'},
#  {'id': '11958757156',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 197488368,
#    'name': 'GoldenMaximo/portfolio',
#    'url': 'https://api.github.com/repos/GoldenMaximo/portfolio'},
#   'payload': {'action': 'opened',
#    'number': 3,
#    'pull_request': {'url': 'https://api.github.com/repos/GoldenMaximo/portfolio/pulls/3',
#     'id': 398693208,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mzk4NjkzMjA4',
#     'html_url': 'https://github.com/GoldenMaximo/portfolio/pull/3',
#     'diff_url': 'https://github.com/GoldenMaximo/portfolio/pull/3.diff',
#     'patch_url': 'https://github.com/GoldenMaximo/portfolio/pull/3.patch',
#     'issue_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/issues/3',
#     'number': 3,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump acorn from 5.7.3 to 5.7.4',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [acorn](https://github.com/acornjs/acorn) from 5.7.3 to 5.7.4.\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/acornjs/acorn/commit/6370e90067552022710190319cbbbd8c43001957"><code>6370e90</code></a> Mark version 5.7.4</li>\n<li><a href="https://github.com/acornjs/acorn/commit/fbc15b1344f6dfb992f67b4bbf1357436247c8a0"><code>fbc15b1</code></a> More rigorously check surrogate pairs in regexp validator</li>\n<li>See full diff in <a href="https://github.com/acornjs/acorn/compare/5.7.3...5.7.4">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=acorn&package-manager=npm_and_yarn&previous-version=5.7.3&new-version=5.7.4)](https://help.github.com/articles/configuring-automated-security-fixes)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n\nYou can disable automated security fix PRs for this repo from the [Security Alerts page](https://github.com/GoldenMaximo/portfolio/network/alerts).\n\n</details>',
#     'created_at': '2020-04-04T19:15:58Z',
#     'updated_at': '2020-04-04T19:15:58Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/pulls/3/commits',
#     'review_comments_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/pulls/3/comments',
#     'review_comment_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/issues/3/comments',
#     'statuses_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/statuses/75a45c7d5d95db136786d711b20c79f8caf213c8',
#     'head': {'label': 'GoldenMaximo:dependabot/npm_and_yarn/acorn-5.7.4',
#      'ref': 'dependabot/npm_and_yarn/acorn-5.7.4',
#      'sha': '75a45c7d5d95db136786d711b20c79f8caf213c8',
#      'user': {'login': 'GoldenMaximo',
#       'id': 51284438,
#       'node_id': 'MDQ6VXNlcjUxMjg0NDM4',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/51284438?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/GoldenMaximo',
#       'html_url': 'https://github.com/GoldenMaximo',
#       'followers_url': 'https://api.github.com/users/GoldenMaximo/followers',
#       'following_url': 'https://api.github.com/users/GoldenMaximo/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/GoldenMaximo/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/GoldenMaximo/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/GoldenMaximo/subscriptions',
#       'organizations_url': 'https://api.github.com/users/GoldenMaximo/orgs',
#       'repos_url': 'https://api.github.com/users/GoldenMaximo/repos',
#       'events_url': 'https://api.github.com/users/GoldenMaximo/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/GoldenMaximo/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 197488368,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTc0ODgzNjg=',
#       'name': 'portfolio',
#       'full_name': 'GoldenMaximo/portfolio',
#       'private': False,
#       'owner': {'login': 'GoldenMaximo',
#        'id': 51284438,
#        'node_id': 'MDQ6VXNlcjUxMjg0NDM4',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/51284438?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/GoldenMaximo',
#        'html_url': 'https://github.com/GoldenMaximo',
#        'followers_url': 'https://api.github.com/users/GoldenMaximo/followers',
#        'following_url': 'https://api.github.com/users/GoldenMaximo/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/GoldenMaximo/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/GoldenMaximo/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/GoldenMaximo/subscriptions',
#        'organizations_url': 'https://api.github.com/users/GoldenMaximo/orgs',
#        'repos_url': 'https://api.github.com/users/GoldenMaximo/repos',
#        'events_url': 'https://api.github.com/users/GoldenMaximo/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/GoldenMaximo/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/GoldenMaximo/portfolio',
#       'description': 'My own personal Portfolio made with React',
#       'fork': False,
#       'url': 'https://api.github.com/repos/GoldenMaximo/portfolio',
#       'forks_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/forks',
#       'keys_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/teams',
#       'hooks_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/hooks',
#       'issue_events_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/events',
#       'assignees_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/tags',
#       'blobs_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/languages',
#       'stargazers_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/stargazers',
#       'contributors_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/contributors',
#       'subscribers_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/subscribers',
#       'subscription_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/subscription',
#       'commits_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/merges',
#       'archive_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/downloads',
#       'issues_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/deployments',
#       'created_at': '2019-07-18T01:27:11Z',
#       'updated_at': '2020-01-22T23:53:36Z',
#       'pushed_at': '2020-04-04T19:15:57Z',
#       'git_url': 'git://github.com/GoldenMaximo/portfolio.git',
#       'ssh_url': 'git@github.com:GoldenMaximo/portfolio.git',
#       'clone_url': 'https://github.com/GoldenMaximo/portfolio.git',
#       'svn_url': 'https://github.com/GoldenMaximo/portfolio',
#       'homepage': None,
#       'size': 577,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'GoldenMaximo:master',
#      'ref': 'master',
#      'sha': '8fe131df9bfc498d4c297f4b40e61fad303b2a08',
#      'user': {'login': 'GoldenMaximo',
#       'id': 51284438,
#       'node_id': 'MDQ6VXNlcjUxMjg0NDM4',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/51284438?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/GoldenMaximo',
#       'html_url': 'https://github.com/GoldenMaximo',
#       'followers_url': 'https://api.github.com/users/GoldenMaximo/followers',
#       'following_url': 'https://api.github.com/users/GoldenMaximo/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/GoldenMaximo/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/GoldenMaximo/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/GoldenMaximo/subscriptions',
#       'organizations_url': 'https://api.github.com/users/GoldenMaximo/orgs',
#       'repos_url': 'https://api.github.com/users/GoldenMaximo/repos',
#       'events_url': 'https://api.github.com/users/GoldenMaximo/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/GoldenMaximo/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 197488368,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTc0ODgzNjg=',
#       'name': 'portfolio',
#       'full_name': 'GoldenMaximo/portfolio',
#       'private': False,
#       'owner': {'login': 'GoldenMaximo',
#        'id': 51284438,
#        'node_id': 'MDQ6VXNlcjUxMjg0NDM4',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/51284438?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/GoldenMaximo',
#        'html_url': 'https://github.com/GoldenMaximo',
#        'followers_url': 'https://api.github.com/users/GoldenMaximo/followers',
#        'following_url': 'https://api.github.com/users/GoldenMaximo/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/GoldenMaximo/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/GoldenMaximo/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/GoldenMaximo/subscriptions',
#        'organizations_url': 'https://api.github.com/users/GoldenMaximo/orgs',
#        'repos_url': 'https://api.github.com/users/GoldenMaximo/repos',
#        'events_url': 'https://api.github.com/users/GoldenMaximo/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/GoldenMaximo/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/GoldenMaximo/portfolio',
#       'description': 'My own personal Portfolio made with React',
#       'fork': False,
#       'url': 'https://api.github.com/repos/GoldenMaximo/portfolio',
#       'forks_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/forks',
#       'keys_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/teams',
#       'hooks_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/hooks',
#       'issue_events_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/events',
#       'assignees_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/tags',
#       'blobs_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/languages',
#       'stargazers_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/stargazers',
#       'contributors_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/contributors',
#       'subscribers_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/subscribers',
#       'subscription_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/subscription',
#       'commits_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/GoldenMaximo/portfolio/git/commits{/sha}',
# ...
#    'name': 'mpn0823/Homework-04',
#    'url': 'https://api.github.com/repos/mpn0823/Homework-04'},
#   'payload': {'push_id': 4868409318,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e97706efbac651957b51c63ad9bb500ce848ee92',
#    'before': '4e62e8e6baf4f32027b01c5e3cada6f4347eb861',
#    'commits': [{'sha': 'e97706efbac651957b51c63ad9bb500ce848ee92',
#      'author': {'email': 'michael.p.nance@gmail.com',
#       'name': 'Michael P Nance'},
#      'message': 'HTML, question and answer object constructor and manipulation functions done',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mpn0823/Homework-04/commits/e97706efbac651957b51c63ad9bb500ce848ee92'}]},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z'},
#  {'id': '11958757129',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 197488368,
#    'name': 'GoldenMaximo/portfolio',
#    'url': 'https://api.github.com/repos/GoldenMaximo/portfolio'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/acorn-5.7.4',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'My own personal Portfolio made with React',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z'},
#  {'id': '11958757123',
#   'type': 'PushEvent',
#   'actor': {'id': 49232422,
#    'login': 'majamanojlovic',
#    'display_login': 'majamanojlovic',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/majamanojlovic',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49232422?'},
#   'repo': {'id': 97681096,
#    'name': 'raspberrypilearning/tell-a-story',
#    'url': 'https://api.github.com/repos/raspberrypilearning/tell-a-story'},
#   'payload': {'push_id': 4868409316,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/l10n_master',
#    'head': '6f634272298a2539987f86b03694e0353942e106',
#    'before': '848dcaa73c7b93b71f90b8651851885ffc78df01',
#    'commits': [{'sha': '6f634272298a2539987f86b03694e0353942e106',
#      'author': {'email': '49232422+majamanojlovic@users.noreply.github.com',
#       'name': 'majamanojlovic'},
#      'message': 'New translations step_7.md (Catalan)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/raspberrypilearning/tell-a-story/commits/6f634272298a2539987f86b03694e0353942e106'}]},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z',
#   'org': {'id': 6546294,
#    'login': 'raspberrypilearning',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/raspberrypilearning',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6546294?'}},
#  {'id': '11958757127',
#   'type': 'CreateEvent',
#   'actor': {'id': 2637036,
#    'login': 'VaughnVernon',
#    'display_login': 'VaughnVernon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/VaughnVernon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2637036?'},
#   'repo': {'id': 115405309,
#    'name': 'vlingo/vlingo-cluster',
#    'url': 'https://api.github.com/repos/vlingo/vlingo-cluster'},
#   'payload': {'ref': '1.2.16',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': 'The vlingo/PLATFORM cluster management for reactive, scalable resiliency of JVM tools and applications running on vlingo/actors.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z',
#   'org': {'id': 26832303,
#    'login': 'vlingo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/vlingo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26832303?'}},
#  {'id': '11958757122',
#   'type': 'PushEvent',
#   'actor': {'id': 1146234,
#    'login': 'mbrazeau',
#    'display_login': 'mbrazeau',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mbrazeau',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1146234?'},
#   'repo': {'id': 2630436,
#    'name': 'mbrazeau/MorphyWeb',
#    'url': 'https://api.github.com/repos/mbrazeau/MorphyWeb'},
#   'payload': {'push_id': 4868409315,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '229c8178ec2369a1e433a926c06e666c988c8f11',
#    'before': '507331e775f0167fb21399b98b8dcc87c600c9c9',
#    'commits': [{'sha': '229c8178ec2369a1e433a926c06e666c988c8f11',
#      'author': {'email': 'martin.brazeau@gmail.com', 'name': 'Martin Brazeau'},
#      'message': 'add new custom colour gradient',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mbrazeau/MorphyWeb/commits/229c8178ec2369a1e433a926c06e666c988c8f11'}]},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z'},
#  {'id': '11958757126',
#   'type': 'WatchEvent',
#   'actor': {'id': 24607388,
#    'login': 'Raul6469',
#    'display_login': 'Raul6469',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Raul6469',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24607388?'},
#   'repo': {'id': 72799153,
#    'name': 'rust-embedded/discovery',
#    'url': 'https://api.github.com/repos/rust-embedded/discovery'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z',
#   'org': {'id': 17707713,
#    'login': 'rust-embedded',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/rust-embedded',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17707713?'}},
#  {'id': '11958757120',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 197385601,
#    'name': 'ritoshyadav/react-project',
#    'url': 'https://api.github.com/repos/ritoshyadav/react-project'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/acorn-5.7.4',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z'},
#  {'id': '11958757117',
#   'type': 'PushEvent',
#   'actor': {'id': 54482114,
#    'login': 'othwsav',
#    'display_login': 'othwsav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/othwsav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54482114?'},
#   'repo': {'id': 245706429,
#    'name': 'othwsav/Sass-Practical-Example',
#    'url': 'https://api.github.com/repos/othwsav/Sass-Practical-Example'},
#   'payload': {'push_id': 4868409314,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9661bb24e38c0ce17ddd99102c6edb826b29d8fc',
#    'before': '67500dd3c57f6224a3bd6e0e0b33d5a4e5026039',
#    'commits': [{'sha': '9661bb24e38c0ce17ddd99102c6edb826b29d8fc',
#      'author': {'email': '54482114+othwsav@users.noreply.github.com',
#       'name': 'othwsav'},
#      'message': 'I added a local Storage thing so when you refresh the page you do not lose the theme',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/othwsav/Sass-Practical-Example/commits/9661bb24e38c0ce17ddd99102c6edb826b29d8fc'}]},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z'},
#  {'id': '11958757116',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 148436575,
#    'name': 'Bazzer588/test-bp-356',
#    'url': 'https://api.github.com/repos/Bazzer588/test-bp-356'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/acorn-5.7.4',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z'},
#  {'id': '11958757114',
#   'type': 'PushEvent',
#   'actor': {'id': 2637036,
#    'login': 'VaughnVernon',
#    'display_login': 'VaughnVernon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/VaughnVernon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2637036?'},
#   'repo': {'id': 115405309,
#    'name': 'vlingo/vlingo-cluster',
#    'url': 'https://api.github.com/repos/vlingo/vlingo-cluster'},
#   'payload': {'push_id': 4868409310,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '5fa90f524fceb4f6edee05c36e1e9e976540e9b8',
#    'before': '009b8f99a2c3447149fa53bd7232000c0bfe28cb',
#    'commits': [{'sha': 'c1059e5c7d21c9867f747d7f1892b110b5e85ff4',
#      'author': {'email': 'VaughnVernon',
#       'name': 'vaughn@forcomprehension.com'},
#      'message': 'Release v1.2.16',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/vlingo/vlingo-cluster/commits/c1059e5c7d21c9867f747d7f1892b110b5e85ff4'},
#     {'sha': '5fa90f524fceb4f6edee05c36e1e9e976540e9b8',
#      'author': {'email': 'VaughnVernon',
#       'name': 'vaughn@forcomprehension.com'},
#      'message': 'Next development version 1.2.17-SNAPSHOT',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/vlingo/vlingo-cluster/commits/5fa90f524fceb4f6edee05c36e1e9e976540e9b8'}]},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z',
#   'org': {'id': 26832303,
#    'login': 'vlingo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/vlingo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26832303?'}},
#  {'id': '11958757109',
#   'type': 'PushEvent',
#   'actor': {'id': 24585160,
#    'login': 'tornikegomareli',
#    'display_login': 'tornikegomareli',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tornikegomareli',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24585160?'},
#   'repo': {'id': 253002572,
#    'name': 'tornikegomareli/NGBCurrencyNET',
#    'url': 'https://api.github.com/repos/tornikegomareli/NGBCurrencyNET'},
#   'payload': {'push_id': 4868409307,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e564fbf2f0b962e67db383186b234cb74ad9a777',
#    'before': '00359312b42c1051b3624dfd8d5867447b0815f8',
#    'commits': [{'sha': 'e564fbf2f0b962e67db383186b234cb74ad9a777',
#      'author': {'email': 't.gomareli@upcast.ge', 'name': 'Tornike Gomareli'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tornikegomareli/NGBCurrencyNET/commits/e564fbf2f0b962e67db383186b234cb74ad9a777'}]},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z'},
#  {'id': '11958757107',
#   'type': 'PushEvent',
#   'actor': {'id': 12595948,
#    'login': 'yichahucha',
#    'display_login': 'yichahucha',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yichahucha',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12595948?'},
#   'repo': {'id': 183581938,
#    'name': 'yichahucha/surge',
#    'url': 'https://api.github.com/repos/yichahucha/surge'},
#   'payload': {'push_id': 4868409304,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2438cbe25536087bb986d0bae3185150d67727f0',
#    'before': '556667d0851fd0f8f1112824bdff43fb98daa225',
#    'commits': [{'sha': '2438cbe25536087bb986d0bae3185150d67727f0',
#      'author': {'email': '12595948+yichahucha@users.noreply.github.com',
#       'name': 'tern'},
#      'message': 'update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/yichahucha/surge/commits/2438cbe25536087bb986d0bae3185150d67727f0'}]},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z'},
#  {'id': '11958757105',
#   'type': 'PushEvent',
#   'actor': {'id': 39853884,
#    'login': 'Kichiyaki',
#    'display_login': 'Kichiyaki',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Kichiyaki',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39853884?'},
#   'repo': {'id': 253079894,
#    'name': 'Kichiyaki/dawid-wysokinski.pl',
#    'url': 'https://api.github.com/repos/Kichiyaki/dawid-wysokinski.pl'},
#   'payload': {'push_id': 4868409306,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c2dbc34df8930405af6b48f42c6761c65c030438',
#    'before': 'd5556640bd2c023266e0a23b14a8a7b21c72956b',
#    'commits': [{'sha': 'c2dbc34df8930405af6b48f42c6761c65c030438',
#      'author': {'email': 'xyztojajestem@gmail.com',
#       'name': 'Dawid Wysokiński'},
#      'message': 'update readme.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Kichiyaki/dawid-wysokinski.pl/commits/c2dbc34df8930405af6b48f42c6761c65c030438'}]},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z'},
#  {'id': '11958757108',
#   'type': 'IssuesEvent',
#   'actor': {'id': 980388,
#    'login': 'pel-daniel',
#    'display_login': 'pel-daniel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pel-daniel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/980388?'},
#   'repo': {'id': 244738808,
#    'name': 'minimalistOrg/minimalist-ide',
#    'url': 'https://api.github.com/repos/minimalistOrg/minimalist-ide'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/minimalistOrg/minimalist-ide/issues/4',
#     'repository_url': 'https://api.github.com/repos/minimalistOrg/minimalist-ide',
#     'labels_url': 'https://api.github.com/repos/minimalistOrg/minimalist-ide/issues/4/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/minimalistOrg/minimalist-ide/issues/4/comments',
#     'events_url': 'https://api.github.com/repos/minimalistOrg/minimalist-ide/issues/4/events',
#     'html_url': 'https://github.com/minimalistOrg/minimalist-ide/issues/4',
#     'id': 594009962,
#     'node_id': 'MDU6SXNzdWU1OTQwMDk5NjI=',
#     'number': 4,
#     'title': 'Recursive function navigation',
#     'user': {'login': 'pel-daniel',
#      'id': 980388,
#      'node_id': 'MDQ6VXNlcjk4MDM4OA==',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/980388?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pel-daniel',
#      'html_url': 'https://github.com/pel-daniel',
#      'followers_url': 'https://api.github.com/users/pel-daniel/followers',
#      'following_url': 'https://api.github.com/users/pel-daniel/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pel-daniel/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pel-daniel/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pel-daniel/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pel-daniel/orgs',
#      'repos_url': 'https://api.github.com/users/pel-daniel/repos',
#      'events_url': 'https://api.github.com/users/pel-daniel/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pel-daniel/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-04-04T19:15:57Z',
#     'updated_at': '2020-04-04T19:15:57Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
#     'body': 'What to do for navigation inside a recursive function?\r\nOpen the function again to the right?'}},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z',
#   'org': {'id': 61759654,
#    'login': 'minimalistOrg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/minimalistOrg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61759654?'}},
#  {'id': '11958757110',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 197419529,
#    'name': 'ivymichael/todolist_angular',
#    'url': 'https://api.github.com/repos/ivymichael/todolist_angular'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/acorn-6.4.1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Angular todolist example',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-04-04T19:15:58Z'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e88de1b-0281a9ecd686e7a0bad88b84'},
#  'origin': '220.129.176.244',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e88de1b-95af098e5f490a71e1e13099'},
#  'json': None,
#  'origin': '220.129.176.244',
#  'url': 'http://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e88de1c-12d5b279fa73b8dd6f34b240'},
#  'json': None,
#  'origin': '220.129.176.244',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
